# %% [markdown]
# # Test di jupyter
#
# Selezionare la prima cella (questa) e premere SHIFT+INVIO.
# Una volta fatto verrà elaborata la cella e evindenziata quella successiva.
#
# Continuare a premere SHIFT+INVIO in modo da elaborare il contenuto di tutte le celle.
# Se nessuna mostra errori, siete pronti per seguire la prima lezione si python.
#
# In caso di problemi scrivere ad uno dei seguenti indirizzi email:
#
# Camillo Tassi : camillo.tassi@uniroma3.it
#
# Simone Romiti : simone.romiti@uniroma3.it

# %%
a = 5
b = "ciao"
print(b, 5)
# Out:
# ciao 5

# %%
import numpy as np
print(np.pi)
# Out:
# 3.141592653589793

# %%
from sympy import *
from sympy.plotting import *
x, y, z = symbols("x, y, z")

# %%
plot(exp(x), (x,-3,2))

# %%
# %matplotlib notebook
plot3d(cos(x)*sin(x), (x,-5,5),(y,-5,5))
